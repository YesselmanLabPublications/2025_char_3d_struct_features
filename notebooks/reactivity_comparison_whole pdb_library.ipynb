# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from dms_3d_features.plotting import plot_motif_boxplot_stripplot_with_whole_pdb_reactivity
import numpy as np

# %%
DATA_PATH = "../dms_3d_features/resources/csvs"

# %%
df = pd.read_csv(f'{DATA_PATH}/dms_comparison_with_z_score.csv')

# %% [markdown]
# # 1U9S

# %%
df_sub = df.query("pdb_id == '1U9S' and m_sequence =='CAC&GCG'").copy()
print(df_sub["r_data"].dtype)
# Out:
# object

# %%
df_sub = df.query("pdb_id == '1U9S' and m_sequence =='CAC&GCG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '1U9S' and m_sequence =='CAAG&CG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '1U9S' and m_sequence =='GAC&GC'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df['pdb_id'] == '1U9S') & (df['within_range'] == 'NO')]
# Out:
#   pdb_id m_sequence m_structure  motif_number nucleotide ss_nt   average  \
# 2   1U9S    CAC&GCG     (.(&).)             1          C     (  0.001535
# 5   1U9S    CAC&GCG     (.(&).)             1          C     .  0.008570
# 7   1U9S    CAAG&CG     (..(&))             1          C     (  0.002864
#
#         std  r_loc_pos      type  dms_whole_rna  \
# 2  0.001259          5    Paired        0.00491
# 5  0.001532         11  Junction        0.00336
# 7  0.001996          3    Paired        0.00000
#
#                                               r_data has_pdb within_range  \
# 2  [0.00059, 0.00072, 0.00629, 0.00111, 0.00096, ...      NO           NO
# 5  [0.01023, 0.00799, 0.01428, 0.00683, 0.00823, ...      NO           NO
# 7  [0.00128, 0.00282, 0.00272, 0.00352, 0.00251, ...     YES           NO
#
#     z-score
# 2  2.681253
# 5 -3.401453
# 7 -1.434775

# %% [markdown]
# # C0006

# %%
df_sub = df.query("pdb_id == 'C0006' and m_sequence =='CAC&GG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df['pdb_id'] == 'C0006') & (df['within_range'] == 'NO')]
# Out:
# Empty DataFrame
# Columns: [pdb_id, m_sequence, m_structure, motif_number, nucleotide, ss_nt, average, std, r_loc_pos, type, dms_whole_rna, r_data, has_pdb, within_range, z-score]
# Index: []

# %% [markdown]
# # 3D0U

# %%
df_sub = df.query("pdb_id == '3D0U' and m_sequence =='CGAG&CGAG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '3D0U' and m_sequence =='CAC&GGG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df['pdb_id'] == '3D0U') & (df['within_range'] == 'NO')]
# Out:
#    pdb_id m_sequence m_structure  motif_number nucleotide ss_nt   average  \
# 37   3D0U    CAC&GGG     (.(&).)             1          C     )  0.001707
#
#          std  r_loc_pos    type  dms_whole_rna  \
# 37  0.000926          5  Paired        0.00282
#
#                                                r_data has_pdb within_range  \
# 37  [0.00089, 0.00138, 0.00116, 0.0049, 0.00106, 0...     YES           NO
#
#      z-score
# 37  1.202242

# %% [markdown]
# # 2OIU

# %%
df_sub = df.query("pdb_id == '2OIU' and m_sequence =='CGACCA&UCUUAG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df['pdb_id'] == '2OIU') & (df['within_range'] == 'NO')]
# Out:
#    pdb_id     m_sequence    m_structure  motif_number nucleotide ss_nt  \
# 47   2OIU  CGACCA&UCUUAG  (....(&)....)             1          A     (
#
#     average       std  r_loc_pos    type  dms_whole_rna  \
# 47  0.00189  0.000918          8  Paired        0.00806
#
#                                                r_data has_pdb within_range  \
# 47  [0.00172, 0.00247, 0.00421, 0.00202, 0.00252, ...     YES           NO
#
#      z-score
# 47  6.722044

# %% [markdown]
# # 4AOB

# %%
df_sub = df.query("pdb_id == '4AOB' and m_sequence =='GAG&CC'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '4AOB' and m_sequence =='CGU&GAG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df['pdb_id'] == '4AOB') & (df['within_range'] == 'NO')]
# Out:
#    pdb_id m_sequence m_structure  motif_number nucleotide ss_nt   average  \
# 59   4AOB     GAG&CC      (.(&))             1          C     )  0.001295
# 60   4AOB     GAG&CC      (.(&))             1          C     )  0.001081
# 61   4AOB    CGU&GAG     (.(&).)             1          C     (  0.001644
#
#          std  r_loc_pos    type  dms_whole_rna  \
# 59  0.000566         10  Paired        0.00845
# 60  0.000443         11  Paired        0.01398
# 61  0.001090          3  Paired        0.03059
#
#                                                r_data has_pdb within_range  \
# 59  [0.00202, 0.00131, 0.00132, 0.00117, 0.00121, ...      NO           NO
# 60  [0.00236, 0.0008, 0.00156, 0.00129, 0.00055, 0...      NO           NO
# 61  [0.00138, 0.00131, 0.00212, 0.00153, 0.00153, ...     YES           NO
#
#       z-score
# 59  12.640641
# 60  29.085885
# 61  26.549472

# %% [markdown]
# # 4K27

# %%
df_sub = df.query("pdb_id == '4K27' and m_sequence =='CUAAG&UAUG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '4K27' and m_sequence =='CCUG&CCUG' and motif_number == 1").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '4K27' and m_sequence =='CCUG&CCUG' and motif_number == 2").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '4K27' and m_sequence =='CCUG&CCUG' and motif_number == 3").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df['pdb_id'] == '4K27') & (df['within_range'] == 'NO')]
# Out:
#     pdb_id m_sequence m_structure  motif_number nucleotide ss_nt   average  \
# 78    4K27  CCUG&CCUG   (..(&)..)             1          C     (  0.001439
# 93    4K27  CCUG&CCUG   (..(&)..)             2          C     .  0.003646
# 96    4K27  CCUG&CCUG   (..(&)..)             3          C     (  0.001439
# 102   4K27  CCUG&CCUG   (..(&)..)             3          C     .  0.003646
#
#           std  r_loc_pos      type  dms_whole_rna  \
# 78   0.001086          3    Paired        0.00338
# 93   0.000754         12  Junction        0.00045
# 96   0.001086          3    Paired        0.00473
# 102  0.000754         12  Junction        0.00068
#
#                                                 r_data has_pdb within_range  \
# 78   [0.00383, 0.0011, 0.00091, 0.00073, 0.0014, 0....     YES           NO
# 93   [0.0044, 0.00378, 0.00304, 0.0024, 0.00307, 0....     YES           NO
# 96   [0.00383, 0.0011, 0.00091, 0.00073, 0.0014, 0....     YES           NO
# ...

# %% [markdown]
# # 4KQY

# %%
df_sub = df.query("pdb_id == '4KQY' and m_sequence =='CGACGAAG&CAGAG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '4KQY' and m_sequence =='CAAG&CG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df['pdb_id'] == '4KQY') & (df['within_range'] == 'NO')]
# Out:
#     pdb_id      m_sequence     m_structure  motif_number nucleotide ss_nt  \
# 117   4KQY  CGACGAAG&CAGAG  (......(&)...)             1          A     .
#
#       average       std  r_loc_pos      type  dms_whole_rna  \
# 117  0.016921  0.006641         18  Junction        0.00242
#
#                                                 r_data has_pdb within_range  \
# 117  [0.01043, 0.01645, 0.01504, 0.01384, 0.01128, ...     YES           NO
#
#       z-score
# 117 -2.183625

# %% [markdown]
# # 4RUM

# %%
df_sub = df.query("pdb_id == '4RUM' and m_sequence =='UGCAG&CAA'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df['pdb_id'] == '4RUM') & (df['within_range'] == 'NO')]
# Out:
# Empty DataFrame
# Columns: [pdb_id, m_sequence, m_structure, motif_number, nucleotide, ss_nt, average, std, r_loc_pos, type, dms_whole_rna, r_data, has_pdb, within_range, z-score]
# Index: []

# %% [markdown]
# # 5BTM

# %%
df_sub = df.query("pdb_id == '5BTM' and m_sequence =='UUCUA&UUCUA' and motif_number== 1").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '5BTM' and m_sequence =='UUCUA&UUCUA' and motif_number== 2").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '5BTM' and m_sequence =='CUAAG&UAUG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df['pdb_id'] == '5BTM') & (df['within_range'] == 'NO')]
# Out:
#     pdb_id   m_sequence  m_structure  motif_number nucleotide ss_nt   average  \
# 139   5BTM  UUCUA&UUCUA  (...(&)...)             1          A     (  0.001126
# 143   5BTM  UUCUA&UUCUA  (...(&)...)             1          C     .  0.002913
#
#           std  r_loc_pos      type  dms_whole_rna  \
# 139  0.000494          7    Paired        0.00232
# 143  0.000836         14  Junction        0.00139
#
#                                                 r_data has_pdb within_range  \
# 139  [0.00128, 0.00082, 0.00139, 0.00068, 0.00087, ...     YES           NO
# 143  [0.00222, 0.0021, 0.00275, 0.00149, 0.00227, 0...     YES           NO
#
#       z-score
# 139  2.416619
# 143 -1.822615

# %% [markdown]
# # 5FJC

# %%
df_sub = df.query("pdb_id == '5FJC' and m_sequence =='CGAAGAAC&GGGAG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '5FJC' and m_sequence =='GAG&CC'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df['pdb_id'] == '5FJC') & (df['within_range'] == 'NO')]
# Out:
#     pdb_id      m_sequence     m_structure  motif_number nucleotide ss_nt  \
# 167   5FJC  CGAAGAAC&GGGAG  (......(&)...)             1          C     (
# 174   5FJC  CGAAGAAC&GGGAG  (......(&)...)             1          C     (
# 185   5FJC          GAG&CC          (.(&))             1          C     )
# 186   5FJC          GAG&CC          (.(&))             1          C     )
#
#       average       std  r_loc_pos    type  dms_whole_rna  \
# 167  0.001455  0.000637          3  Paired        0.01284
# 174  0.001996  0.000797         10  Paired        0.00510
# 185  0.001295  0.000566         10  Paired        0.01060
# 186  0.001081  0.000443         11  Paired        0.00326
#
#                                                 r_data has_pdb within_range  \
# 167  [0.00168, 0.00119, 0.00141, 0.00125, 0.00154, ...     YES           NO
# 174  [0.00236, 0.00135, 0.00154, 0.00203, 0.00131, ...     YES           NO
# ...

# %% [markdown]
# # 5M0H

# %%
df_sub = df.query("pdb_id == '5M0H' and m_sequence =='ACU&AU'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '5M0H' and m_sequence =='GAAU&AC'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '5M0H' and m_sequence =='CUAAG&UAUG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df['pdb_id'] == '5M0H') & (df['within_range'] == 'NO')]
# Out:
#     pdb_id m_sequence m_structure  motif_number nucleotide ss_nt   average  \
# 188   5M0H     ACU&AU      (.(&))             1          C     .  0.028392
# 194   5M0H    GAAU&AC     (..(&))             1          A     .  0.017790
# 197   5M0H    GAAU&AC     (..(&))             1          A     )  0.005573
# 198   5M0H    GAAU&AC     (..(&))             1          C     )  0.001913
#
#           std  r_loc_pos      type  dms_whole_rna  \
# 188  0.007682          4  Junction        0.01528
# 194  0.004624          4  Junction        0.00802
# 197  0.001729         11    Paired        0.00153
# 198  0.000678         12    Paired        0.00344
#
#                                                 r_data has_pdb within_range  \
# 188  [0.02998, 0.02263, 0.02773, 0.02668, 0.02298, ...      NO           NO
# 194  [0.01051, 0.02093, 0.02247, 0.0144, 0.02142, 0...      NO           NO
# 197  [0.00711, 0.00492, 0.0064, 0.00602, 0.00505, 0...      NO           NO
# ...
