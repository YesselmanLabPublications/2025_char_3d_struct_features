# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from dms_3d_features.plotting import (
    plot_motif_boxplot_stripplot_with_whole_pdb_reactivity,
)
import numpy as np

# %%
DATA_PATH = "../dms_3d_features/resources/jsons"

# %%
df = pd.read_json(f"{DATA_PATH}/dms_comparison_with_z_score.json")

# %%
df.columns
# Out:
# Index(['pdb_id', 'm_sequence', 'm_structure', 'motif_number', 'nucleotide',
#        'average', 'std', 'pdb_r_pos', 'whole_rna_reac', 'r_data', 'has_pdb',
#        'within_boxplot_range', 'z_score'],
#       dtype='object')

# %%
for i, g in df.groupby(["within_boxplot_range", "has_pdb"]):
    print(i, len(g))
# Out:
# ('-', 'NO') 26
# ('-', 'YES') 84
# ('NO', 'NO') 10
# ('NO', 'YES') 13
# ('YES', 'NO') 18
# ('YES', 'YES') 58

# %% [markdown]
# # 1U9S

# %%
df_sub = df.query("pdb_id == '1U9S' and m_sequence =='CAC&GCG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '1U9S' and m_sequence =='CAAG&CG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '1U9S' and m_sequence =='GAC&GC'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df["pdb_id"] == "1U9S") & (df["within_boxplot_range"] == "NO")]
# Out:
#   pdb_id m_sequence m_structure  motif_number nucleotide   average       std  \
# 2   1U9S    CAC&GCG     (.(&).)             1          C  0.001535  0.001259
# 5   1U9S    CAC&GCG     (.(&).)             1          C  0.008570  0.001532
# 7   1U9S    CAAG&CG     (..(&))             1          C  0.002864  0.001996
#
#    pdb_r_pos  whole_rna_reac  \
# 2          5         0.00491
# 5         11         0.00336
# 7          3         0.00000
#
#                                               r_data has_pdb  \
# 2  [0.00059, 0.00072, 0.0062900000000000005, 0.00...      NO
# 5  [0.010230000000000001, 0.00799, 0.014280000000...      NO
# 7  [0.00128, 0.00282, 0.00272, 0.00352, 0.00251, ...     YES
#
#   within_boxplot_range   z_score
# 2                   NO  2.681253
# 5                   NO -3.401453
# 7                   NO -1.434775

# %% [markdown]
# # C0006

# %%
df_sub = df.query("pdb_id == 'C0006' and m_sequence =='CAC&GG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df["pdb_id"] == "C0006") & (df["within_boxplot_range"] == "NO")]
# Out:
# Empty DataFrame
# Columns: [pdb_id, m_sequence, m_structure, motif_number, nucleotide, average, std, pdb_r_pos, whole_rna_reac, r_data, has_pdb, within_boxplot_range, z_score]
# Index: []

# %% [markdown]
# # 3D0U

# %%
df_sub = df.query("pdb_id == '3D0U' and m_sequence =='CGAG&CGAG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '3D0U' and m_sequence =='CAC&GGG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df["pdb_id"] == "3D0U") & (df["within_boxplot_range"] == "NO")]
# Out:
#    pdb_id m_sequence m_structure  motif_number nucleotide   average       std  \
# 37   3D0U    CAC&GGG     (.(&).)             1          C  0.001707  0.000926
#
#     pdb_r_pos  whole_rna_reac  \
# 37          5         0.00282
#
#                                                r_data has_pdb  \
# 37  [0.0008900000000000001, 0.0013800000000000002,...     YES
#
#    within_boxplot_range   z_score
# 37                   NO  1.202242

# %% [markdown]
# # 2OIU

# %%
df_sub = df.query("pdb_id == '2OIU' and m_sequence =='CGACCA&UCUUAG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df["pdb_id"] == "2OIU") & (df["within_boxplot_range"] == "NO")]
# Out:
#    pdb_id     m_sequence    m_structure  motif_number nucleotide  average  \
# 47   2OIU  CGACCA&UCUUAG  (....(&)....)             1          A  0.00189
#
#          std  pdb_r_pos  whole_rna_reac  \
# 47  0.000918          8         0.00806
#
#                                                r_data has_pdb  \
# 47  [0.0017200000000000002, 0.0024700000000000004,...     YES
#
#    within_boxplot_range   z_score
# 47                   NO  6.722044

# %% [markdown]
# # 4AOB

# %%
df_sub = df.query("pdb_id == '4AOB' and m_sequence =='GAG&CC'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '4AOB' and m_sequence =='CGU&GAG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df["pdb_id"] == "4AOB") & (df["within_boxplot_range"] == "NO")]
# Out:
#    pdb_id m_sequence m_structure  motif_number nucleotide   average       std  \
# 59   4AOB     GAG&CC      (.(&))             1          C  0.001295  0.000566
# 60   4AOB     GAG&CC      (.(&))             1          C  0.001081  0.000443
# 61   4AOB    CGU&GAG     (.(&).)             1          C  0.001644  0.001090
#
#     pdb_r_pos  whole_rna_reac  \
# 59         10         0.00845
# 60         11         0.01398
# 61          3         0.03059
#
#                                                r_data has_pdb  \
# 59  [0.00202, 0.0013100000000000002, 0.00132000000...      NO
# 60  [0.00236, 0.0008, 0.0015600000000000002, 0.001...      NO
# 61  [0.0013800000000000002, 0.0013100000000000002,...     YES
#
#    within_boxplot_range    z_score
# 59                   NO  12.640641
# 60                   NO  29.085885
# 61                   NO  26.549472

# %% [markdown]
# # 4K27

# %%
df_sub = df.query("pdb_id == '4K27' and m_sequence =='CUAAG&UAUG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query(
    "pdb_id == '4K27' and m_sequence =='CCUG&CCUG' and motif_number == 1"
).copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query(
    "pdb_id == '4K27' and m_sequence =='CCUG&CCUG' and motif_number == 2"
).copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query(
    "pdb_id == '4K27' and m_sequence =='CCUG&CCUG' and motif_number == 3"
).copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df["pdb_id"] == "4K27") & (df["within_boxplot_range"] == "NO")]
# Out:
#     pdb_id m_sequence m_structure  motif_number nucleotide   average  \
# 78    4K27  CCUG&CCUG   (..(&)..)             1          C  0.001439
# 93    4K27  CCUG&CCUG   (..(&)..)             2          C  0.003646
# 96    4K27  CCUG&CCUG   (..(&)..)             3          C  0.001439
# 102   4K27  CCUG&CCUG   (..(&)..)             3          C  0.003646
#
#           std  pdb_r_pos  whole_rna_reac  \
# 78   0.001086          3         0.00338
# 93   0.000754         12         0.00045
# 96   0.001086          3         0.00473
# 102  0.000754         12         0.00068
#
#                                                 r_data has_pdb  \
# 78   [0.0038300000000000005, 0.0011, 0.000910000000...     YES
# 93   [0.0044, 0.0037800000000000004, 0.00304, 0.002...     YES
# 96   [0.0038300000000000005, 0.0011, 0.000910000000...     YES
# 102  [0.0044, 0.0037800000000000004, 0.00304, 0.002...     YES
#
#     within_boxplot_range   z_score
# 78                    NO  1.787489
# 93                    NO -4.236951
# 96                    NO  3.030960
# 102                   NO -3.932063

# %% [markdown]
# # 4KQY

# %%
df_sub = df.query("pdb_id == '4KQY' and m_sequence =='CGACGAAG&CAGAG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '4KQY' and m_sequence =='CAAG&CG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df["pdb_id"] == "4KQY") & (df["within_boxplot_range"] == "NO")]
# Out:
#     pdb_id      m_sequence     m_structure  motif_number nucleotide   average  \
# 117   4KQY  CGACGAAG&CAGAG  (......(&)...)             1          A  0.016921
#
#           std  pdb_r_pos  whole_rna_reac  \
# 117  0.006641         18         0.00242
#
#                                                 r_data has_pdb  \
# 117  [0.01043, 0.016450000000000003, 0.015040000000...     YES
#
#     within_boxplot_range   z_score
# 117                   NO -2.183625

# %% [markdown]
# # 4RUM

# %%
df_sub = df.query("pdb_id == '4RUM' and m_sequence =='UGCAG&CAA'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df["pdb_id"] == "4RUM") & (df["within_boxplot_range"] == "NO")]
# Out:
# Empty DataFrame
# Columns: [pdb_id, m_sequence, m_structure, motif_number, nucleotide, average, std, pdb_r_pos, whole_rna_reac, r_data, has_pdb, within_boxplot_range, z_score]
# Index: []

# %% [markdown]
# # 5BTM

# %%
df_sub = df.query(
    "pdb_id == '5BTM' and m_sequence =='UUCUA&UUCUA' and motif_number== 1"
).copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query(
    "pdb_id == '5BTM' and m_sequence =='UUCUA&UUCUA' and motif_number== 2"
).copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '5BTM' and m_sequence =='CUAAG&UAUG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df["pdb_id"] == "5BTM") & (df["within_boxplot_range"] == "NO")]
# Out:
#     pdb_id   m_sequence  m_structure  motif_number nucleotide   average  \
# 139   5BTM  UUCUA&UUCUA  (...(&)...)             1          A  0.001126
# 143   5BTM  UUCUA&UUCUA  (...(&)...)             1          C  0.002913
#
#           std  pdb_r_pos  whole_rna_reac  \
# 139  0.000494          7         0.00232
# 143  0.000836         14         0.00139
#
#                                                 r_data has_pdb  \
# 139  [0.00128, 0.0008200000000000001, 0.00139000000...     YES
# 143  [0.00222, 0.0021000000000000003, 0.00275000000...     YES
#
#     within_boxplot_range   z_score
# 139                   NO  2.416619
# 143                   NO -1.822615

# %% [markdown]
# # 5FJC

# %%
df_sub = df.query("pdb_id == '5FJC' and m_sequence =='CGAAGAAC&GGGAG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '5FJC' and m_sequence =='GAG&CC'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df["pdb_id"] == "5FJC") & (df["within_boxplot_range"] == "NO")]
# Out:
#     pdb_id      m_sequence     m_structure  motif_number nucleotide   average  \
# 167   5FJC  CGAAGAAC&GGGAG  (......(&)...)             1          C  0.001455
# 174   5FJC  CGAAGAAC&GGGAG  (......(&)...)             1          C  0.001996
# 185   5FJC          GAG&CC          (.(&))             1          C  0.001295
# 186   5FJC          GAG&CC          (.(&))             1          C  0.001081
#
#           std  pdb_r_pos  whole_rna_reac  \
# 167  0.000637          3         0.01284
# 174  0.000797         10         0.00510
# 185  0.000566         10         0.01060
# 186  0.000443         11         0.00326
#
#                                                 r_data has_pdb  \
# 167  [0.00168, 0.00119, 0.00141, 0.00125, 0.0015400...     YES
# 174  [0.00236, 0.00135, 0.0015400000000000001, 0.00...     YES
# 185  [0.00202, 0.0013100000000000002, 0.00132000000...      NO
# 186  [0.00236, 0.0008, 0.0015600000000000002, 0.001...      NO
#
#     within_boxplot_range    z_score
# 167                   NO  17.875602
# 174                   NO   3.897312
# 185                   NO  16.438878
# 186                   NO   4.913322

# %% [markdown]
# # 5M0H

# %%
df_sub = df.query("pdb_id == '5M0H' and m_sequence =='ACU&AU'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '5M0H' and m_sequence =='GAAU&AC'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df_sub = df.query("pdb_id == '5M0H' and m_sequence =='CUAAG&UAUG'").copy()
plot_motif_boxplot_stripplot_with_whole_pdb_reactivity(df_sub)

# %%
df[(df["pdb_id"] == "5M0H") & (df["within_boxplot_range"] == "NO")]
# Out:
#     pdb_id m_sequence m_structure  motif_number nucleotide   average  \
# 188   5M0H     ACU&AU      (.(&))             1          C  0.028392
# 194   5M0H    GAAU&AC     (..(&))             1          A  0.017790
# 197   5M0H    GAAU&AC     (..(&))             1          A  0.005573
# 198   5M0H    GAAU&AC     (..(&))             1          C  0.001913
#
#           std  pdb_r_pos  whole_rna_reac  \
# 188  0.007682          4         0.01528
# 194  0.004624          4         0.00802
# 197  0.001729         11         0.00153
# 198  0.000678         12         0.00344
#
#                                                 r_data has_pdb  \
# 188  [0.029980000000000003, 0.02263, 0.02773, 0.026...      NO
# 194  [0.01051, 0.02093, 0.02247, 0.0144000000000000...      NO
# 197  [0.007110000000000001, 0.004920000000000001, 0...      NO
# 198  [0.0034500000000000004, 0.0018700000000000001,...      NO
#
#     within_boxplot_range   z_score
# 188                   NO -1.706730
# 194                   NO -2.112734
# 197                   NO -2.338120
# 198                   NO  2.253721
